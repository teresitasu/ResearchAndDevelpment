# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The file I want to use is "NASA_Labs_Facilities.xlsx". I will convert it first to ".csv"

# %%
file_xls = pd.read_excel('NASA_Labs_Facilities.xlsx', 'Sheet1' )
file_xls.to_csv('NASA_Labs.csv', encoding = 'Latin-1')

# %%
datafile = pd.read_csv('NASA_Labs.csv', encoding = 'cp1252')

# %%
#Number of rows
len(datafile)
# Out:
# 440

# %%
#Number of columns
len(datafile.columns)
# Out:
# 18

# %% [markdown]
# The file 'NASA_Labs.csv' contains 440 rows and  18 columns

# %%
datafile
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2  \
# 0       Agency        NaN                                             Center
# 1            1        DOD                      Air Force Research Laboratory
# 2            2        DOD                      Air Force Research Laboratory
# 3            3        DOD                      Air Force Research Laboratory
# 4            4        DOD                      Air Force Research Laboratory
# 5            5        DOD              Arnold Engineering Development Center
# 6            6        DOD              Arnold Engineering Development Center
# 7            7        DOD              Arnold Engineering Development Center
# 8            8        DOE              Pacific Northwest National Laboratory
# 9            9        DOE              Pacific Northwest National Laboratory
# 10          10        DOE              Pacific Northwest National Laboratory
# ...
